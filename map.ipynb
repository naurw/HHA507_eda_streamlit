# %% [markdown]
# # Creating an simple yet interactive map to visualize the locations of the hospitals within the csv file that will be analyzed within this repository

# %%
import pandas as pd
import folium

# %%
hospital = pd.read_csv('https://raw.githubusercontent.com/hantswilliams/AHI_STATS_507/main/Week13_Summary/output/df_hospital_2.csv')

# %% [markdown]
# ## Isolating the state of interest

# %%
nyHospitals = hospital[hospital['state'] == 'NY']

# %%
nyHospitals[['Point', 'Longitude', 'Latitude']] = nyHospitals['location'].str.strip('()').str.split(' ', expand=True).rename(columns={0: 'Point', 1:'Longitude', 2:'Latitude'}) 
nyHospitals['Longitude'] = nyHospitals['Longitude'].str.strip('(')
nyHospitals['Longitude'] = nyHospitals['Longitude'].astype(float)
nyHospitals['Latitude'] = pd.to_numeric(nyHospitals['Latitude'])

# %%
nyHospitals.drop(['location'], axis =1, inplace=True)

# %%
nyHospitals.info()

# %%
hMap = nyHospitals[['hospital_name', 'Longitude', 'Latitude']]
hMap = hMap.dropna()

# %%
hMap
# Out:
#                                hospital_name  Longitude   Latitude
# 4     LINCOLN MEDICAL & MENTAL HEALTH CENTER -73.924072  40.817681
# 11                ROCHESTER GENERAL HOSPITAL -77.584424  43.192542
# 12            WYCKOFF HEIGHTS MEDICAL CENTER -73.917648  40.704699
# 20                    QUEENS HOSPITAL CENTER -73.803431  40.716980
# 22                       BRONX HEALTH SYSTEM -73.903756  40.831750
# ...                                      ...        ...        ...
# 5210                             BRYLIN HOSP -78.868415  42.918258
# 5227  SAGAMORE CHILDREN'S PSYCHIATRIC CENTER -73.382467  40.792705
# 5254               HUTCHINGS PSYCHIATRIC CTR -76.139777  43.045384
# 5269                  FOUR WINDS OF SARATOGA -73.783423  43.058364
# 5282                 Keller ACH (West Point) -73.976767  41.400720
#
# [172 rows x 3 columns]

# %%
map = folium.Map(location = [hMap.Latitude.mean(), hMap.Longitude.mean()], zoom_start= 14, control_scale= True)
for index, location_info in hMap.iterrows():
    folium.Marker([location_info['Latitude'], location_info['Longitude']], popup= location_info['hospital_name']).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...
